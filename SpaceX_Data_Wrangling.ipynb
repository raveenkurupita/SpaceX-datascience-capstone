# %% [markdown]
# <a href="https://colab.research.google.com/github/raveenkurupita/SpaceX-datascience-capstone/blob/main/SpaceX_Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. CHECK MISSING VALUES
print("Missing values before:\n", df_api.isnull().sum())

# 2. FILL PayloadMass WITH MEAN - Use .loc to avoid warning
df_api['PayloadMass'] = df_api['PayloadMass'].fillna(df_api['PayloadMass'].mean())

print("\nMissing values after:\n", df_api.isnull().sum())

# 3. CHECK CLASS DISTRIBUTION - IT'S ALREADY THERE
print("\nClass distribution:\n", df_api['Class'].value_counts())
print("\nFirst 8 rows with Class:")
print(df_api[['Class', 'PayloadMass', 'LaunchSite']].head(8))

# 4. SAVE THE FINAL DATASET
df_api.to_csv('dataset_part1.csv', index=False)
print("\n✅ Saved as dataset_part1.csv")
# Out:
# Missing values before:
#  Unnamed: 0                  0
# Flight Number               0
# LaunchSite                  0
# Class                       0
# PayloadMass                 0
# Booster Version             0
# Booster Version Category    0
# dtype: int64
#
# Missing values after:
#  Unnamed: 0                  0
# Flight Number               0
# LaunchSite                  0
# Class                       0
# PayloadMass                 0
# Booster Version             0
# Booster Version Category    0
# dtype: int64
#
# Class distribution:
#  Class
# 0    32
# 1    24
# Name: count, dtype: int64
#
# First 8 rows with Class:
#    Class  PayloadMass   LaunchSite
# 0      0          0.0  CCAFS LC-40
# 1      0          0.0  CCAFS LC-40
# 2      0        525.0  CCAFS LC-40
# 3      0        500.0  CCAFS LC-40
# 4      0        677.0  CCAFS LC-40
# 5      0       3170.0  CCAFS LC-40
# 6      0       3325.0  CCAFS LC-40
# 7      0       2296.0  CCAFS LC-40
#
# ...
