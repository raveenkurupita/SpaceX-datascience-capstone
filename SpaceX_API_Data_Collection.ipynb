# %% [markdown]
# <a href="https://colab.research.google.com/github/raveenkurupita/SpaceX-datascience-capstone/blob/main/SpaceX_API_Data_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install and Import Libraries
# !pip install pandas requests

import requests
import pandas as pd
import numpy as np
import datetime

# %%
# BACKUP DATASET - IBM provides this for when API fails
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv

import pandas as pd
df = pd.read_csv('spacex_launch_dash.csv')

# Rename columns to match what the assignment expects
df = df.rename(columns={'Launch Site':'LaunchSite', 'Payload Mass (kg)':'PayloadMass', 'class':'Class'})

print("Shape of DataFrame:", df.shape) # Should be (121, 8)
df.head(5)
# Out:
# --2026-09-11 04:42:07--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.45.118.108
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.45.118.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2476 (2.4K) [text/csv]
# Saving to: ‘spacex_launch_dash.csv’
#
# spacex_launch_dash. 100%[===================>]   2.42K  --.-KB/s    in 0s
#
# 2026-09-11 04:42:08 (156 MB/s) - ‘spacex_launch_dash.csv’ saved [2476/2476]
#
# Shape of DataFrame: (56, 7)
#    Unnamed: 0  Flight Number   LaunchSite  Class  PayloadMass Booster Version  \
# 0           0              1  CCAFS LC-40      0          0.0  F9 v1.0  B0003
# ...

# %%
df.to_csv('spacex_api_data.csv', index=False)
print("File saved!")
# Out:
# File saved!
